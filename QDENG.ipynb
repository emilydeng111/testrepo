# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ![Screen Shot 2024-07-12 at 21.05.59.png](attachment:b52109a5-55b4-4d36-a8f3-ab117a6b0fda.png)

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Title of the notebook: Final assignment.

# %% [markdown]
# This is a introduction cell.

# %% [markdown]
# Python, R, SQL

# %% [markdown]
# Panda, Matplotlip, Numpy

# %% [markdown]
# TensorFlow, PowerBI, Excel, Jupyter notebook

# %% [markdown]
# 1+2=3

# %%
2*3+6
# Out:
# 12

# %%
# Function to convert minutes to hours
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example usage
minutes = 120
hours = convert_minutes_to_hours(minutes)
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 120 minutes is equal to 2.0 hours.

# %% [markdown]
# - Addition
# - Subtraction
# - Multiplication
# - Division

# %% [markdown]
# Author: Qi Deng Emily
